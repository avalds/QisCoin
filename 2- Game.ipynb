# %% [markdown]
# # Qcoin circuit
# ## Rules:
# 1. You are given a quantum circuit on qubit with a fixed number of gates
# 2. You try to guess the output of the quantum circuit.
#   1. If you are correct you get 1 point
#   2. If you are wrong you get 0 points
# 3. repeat steps 1. and 2. n times to determine your score, and how fast you answered.

# %%
import biased_quantum_coin as qc
from IPython.display import display
print("Welcome to the Qcoin circuit")
qc.play(visualization_mode = "mpl")
# Out:
# Welcome to the Qcoin circuit
# Do you want to play 5, 10 or 20 games? 5
# Do you want easy(e), medium(m) or hard(h) difficulty? m
# The circuit is!
# heads(h)(1) or tails(t)(0)
# 0
# too bad :(
# You have won 0 of the 1 rounds you have played (0.0% winrate)
# The circuit is!
# heads(h)(1) or tails(t)(0)
# 1
# too bad :(
# You have won 0 of the 2 rounds you have played (0.0% winrate)
# The circuit is!
# heads(h)(1) or tails(t)(0)
# 0
# too bad :(
# You have won 0 of the 3 rounds you have played (0.0% winrate)
# The circuit is!
# heads(h)(1) or tails(t)(0)
# 0
# congrats :)
# You have won 1 of the 4 rounds you have played (25.0% winrate)
# The circuit is!
# heads(h)(1) or tails(t)(0)
# 1
# congrats :)
# You have won 2 of the 5 rounds you have played (40.0% winrate)
# It was a highscore enter your name: The best
# highscores:
#                 Name|Score (%)
#             The best|40.0
#              Baldric|0.0
